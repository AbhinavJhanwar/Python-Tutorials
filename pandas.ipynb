# %%
import pandas as pd
from statistics import mean, median, mode

# %%
# read csv/excel
df = pd.read_csv('data/adult.csv')

# %%
# get brief info of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education-num     32561 non-null int64
# marital-status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital-gain      32561 non-null int64
# capital-loss      32561 non-null int64
# hours-per-week    32561 non-null int64
# native-country    32561 non-null object
# income            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
# drop any null values
df.dropna(inplace=True)

# %%
# drop any duplicate rows
df.drop_duplicates(inplace=True)

# %%
# get summary of data of int/real dtyes
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32537.000000  3.253700e+04   32537.000000  32537.000000  32537.000000
# mean      38.585549  1.897808e+05      10.081815   1078.443741     87.368227
# std       13.637984  1.055565e+05       2.571633   7387.957424    403.101833
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.369930e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32537.000000
# mean        40.440329
# std         12.346889
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
# rename columns
df = df.rename(columns={'fnlwgt':'final_weight'})
df.describe()
# Out:
#                 age  final_weight  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
# get unique values of a column
df['workclass'].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
# get number of unique values of a columns
df['workclass'].nunique()
# Out:
# 9

# %%
# get value counts of a column
df['workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64

# %%
# sort dataframe
df.sort_values(by='age').reset_index(drop=True)
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       17            Private  127366           11th              7
# 1       17            Private  132755           11th              7
# 2       17            Private  108470           11th              7
# 3       17          Local-gov  308901           11th              7
# 4       17                  ?   47407           11th              7
# 5       17            Private  222618           11th              7
# 6       17            Private  166242           10th              6
# 7       17            Private  117549           10th              6
# 8       17            Private  114798           10th              6
# 9       17            Private   46402        7th-8th              4
# 10      17            Private  177629           11th              7
# 11      17                  ?   48703           11th              7
# 12      17                  ?  216595           11th              7
# 13      17            Private  197850           11th              7
# 14      17                  ?  634226           10th              6
# 15      17       Self-emp-inc   61838           10th              6
# 16      17            Private  110798           11th              7
# 17      17            Private  167658           12th              8
# 18      17            Private  239346           10th              6
# 19      17            Private  228399           11th              7
# 20      17            Private  114420           11th              7
# 21      17            Private  183110           11th              7
# 22      17            Private   89821           11th              7
# 23      17            Private   73338           11th              7
# 24      17            Private  132680           10th              6
# 25      17          Local-gov  340043           12th              8
# 26      17            Private  365613           10th              6
# 27      17            Private  126771           12th              8
# 28      17            Private  126779           11th              7
# 29      17            Private  225507           11th              7
# ...    ...                ...     ...            ...            ...
# 32531   90                  ?  256514      Bachelors             13
# 32532   90            Private  175491        HS-grad              9
# 32533   90            Private  250832           10th              6
# 32534   90            Private  141758            9th              5
# 32535   90            Private   52386      Bachelors             13
# 32536   90            Private   90523        HS-grad              9
# 32537   90                  ?  166343        1st-4th              2
# 32538   90            Private   52386   Some-college             10
# 32539   90            Private  311184      Bachelors             13
# 32540   90            Private  206667        Masters             14
# 32541   90          Local-gov  153602        HS-grad              9
# 32542   90          Local-gov  187749     Assoc-acdm             12
# 32543   90            Private   87372    Prof-school             15
# 32544   90            Private  137018        HS-grad              9
# 32545   90            Private  313986           11th              7
# 32546   90                  ?  313986        HS-grad              9
# 32547   90                  ?  175444        7th-8th              4
# 32548   90            Private  313749      Bachelors             13
# 32549   90            Private   87285        HS-grad              9
# 32550   90            Private  139660   Some-college             10
# 32551   90            Private   46786      Bachelors             13
# 32552   90                  ?   39824        HS-grad              9
# 32553   90        Federal-gov  195433        HS-grad              9
# 32554   90            Private   40388      Bachelors             13
# 32555   90            Private   88991      Bachelors             13
# 32556   90   Self-emp-not-inc   82628        HS-grad              9
# 32557   90            Private  313749        HS-grad              9
# 32558   90            Private   52386   Some-college             10
# 32559   90                  ?   77053        HS-grad              9
# 32560   90   Self-emp-not-inc  282095   Some-college             10
#
#             marital-status          occupation     relationship  \
# 0            Never-married               Sales        Own-child
# 1            Never-married               Sales        Own-child
# 2            Never-married       Other-service        Own-child
# 3            Never-married        Adm-clerical        Own-child
# 4            Never-married                   ?        Own-child
# 5            Never-married               Sales        Own-child
# 6            Never-married       Other-service        Own-child
# 7            Never-married               Sales   Other-relative
# 8            Never-married       Other-service        Own-child
# 9            Never-married               Sales        Own-child
# 10           Never-married               Sales        Own-child
# 11           Never-married                   ?        Own-child
# 12           Never-married                   ?        Own-child
# 13           Never-married        Adm-clerical        Own-child
# 14           Never-married                   ?        Own-child
# 15           Never-married        Craft-repair        Own-child
# 16           Never-married               Sales        Own-child
# 17           Never-married               Sales        Own-child
# 18           Never-married       Other-service        Own-child
# 19           Never-married       Other-service        Own-child
# 20           Never-married               Sales        Own-child
# 21           Never-married   Handlers-cleaners        Own-child
# 22           Never-married       Other-service        Own-child
# 23           Never-married               Sales        Own-child
# 24           Never-married       Other-service        Own-child
# 25           Never-married        Adm-clerical        Own-child
# 26           Never-married       Other-service        Own-child
# 27           Never-married      Prof-specialty        Own-child
# 28           Never-married       Other-service        Own-child
# 29           Never-married   Handlers-cleaners    Not-in-family
# ...                    ...                 ...              ...
# 32531              Widowed                   ?   Other-relative
# 32532   Married-civ-spouse        Craft-repair          Husband
# 32533   Married-civ-spouse     Exec-managerial          Husband
# 32534        Never-married        Adm-clerical    Not-in-family
# 32535        Never-married      Prof-specialty    Not-in-family
# 32536              Widowed    Transport-moving        Unmarried
# 32537              Widowed                   ?    Not-in-family
# 32538        Never-married       Other-service    Not-in-family
# 32539   Married-civ-spouse               Sales          Husband
# 32540   Married-civ-spouse      Prof-specialty             Wife
# 32541   Married-civ-spouse       Other-service          Husband
# 32542   Married-civ-spouse        Adm-clerical          Husband
# 32543   Married-civ-spouse      Prof-specialty          Husband
# 32544        Never-married       Other-service    Not-in-family
# 32545   Married-civ-spouse        Craft-repair          Husband
# 32546   Married-civ-spouse                   ?          Husband
# 32547            Separated                   ?    Not-in-family
# 32548        Never-married      Prof-specialty        Own-child
# 32549        Never-married       Other-service        Own-child
# 32550             Divorced               Sales        Unmarried
# 32551   Married-civ-spouse               Sales          Husband
# 32552              Widowed                   ?    Not-in-family
# 32553   Married-civ-spouse        Craft-repair          Husband
# 32554        Never-married     Exec-managerial    Not-in-family
# 32555   Married-civ-spouse     Exec-managerial             Wife
# 32556        Never-married     Exec-managerial    Not-in-family
# 32557              Widowed        Adm-clerical        Unmarried
# 32558        Never-married       Other-service    Not-in-family
# 32559              Widowed                   ?    Not-in-family
# 32560   Married-civ-spouse     Farming-fishing          Husband
#
#                       race      sex  capital-gain  capital-loss  \
# 0                    White   Female             0             0
# 1                    White     Male             0             0
# 2                    Black     Male             0             0
# 3                    White   Female             0             0
# 4                    White     Male             0             0
# 5                    Black   Female             0             0
# 6                    White   Female             0             0
# 7                    Black   Female             0             0
# 8                    White   Female             0             0
# 9                    White     Male             0             0
# 10                   White   Female             0             0
# 11                   White   Female             0             0
# 12                   Black   Female             0             0
# 13      Asian-Pac-Islander   Female             0             0
# 14                   White   Female             0             0
# 15                   White     Male             0             0
# 16                   White   Female             0             0
# 17                   White   Female             0             0
# 18                   White     Male             0             0
# 19                   White   Female             0             0
# 20                   White   Female             0             0
# 21                   White     Male             0             0
# 22                   White     Male             0             0
# 23                   White     Male             0             0
# 24                   White   Female             0          1602
# 25                   White   Female             0             0
# 26                   White     Male             0             0
# 27                   White     Male             0             0
# 28                   Black     Male             0             0
# 29                   Black   Female             0             0
# ...                    ...      ...           ...           ...
# 32531                White   Female           991             0
# 32532                White     Male          9386             0
# 32533                White     Male             0             0
# 32534                White   Female             0             0
# 32535   Asian-Pac-Islander     Male             0             0
# 32536                White     Male             0             0
# 32537                Black   Female             0             0
# 32538   Asian-Pac-Islander     Male             0             0
# 32539                White     Male             0             0
# 32540                White   Female             0             0
# 32541                White     Male          6767             0
# 32542   Asian-Pac-Islander     Male             0             0
# 32543                White     Male         20051             0
# 32544                White   Female             0             0
# 32545                White     Male             0             0
# 32546                White     Male             0             0
# 32547                White   Female             0             0
# 32548                White   Female             0             0
# 32549                White   Female             0             0
# 32550                Black   Female             0             0
# 32551                White     Male          9386             0
# 32552                White     Male           401             0
# 32553                White     Male             0             0
# 32554                White     Male             0             0
# 32555                White   Female             0             0
# 32556                White     Male          2964             0
# 32557                White   Female             0             0
# 32558   Asian-Pac-Islander     Male             0             0
# 32559                White   Female             0          4356
# 32560                White     Male             0             0
#
#        hours-per-week  native-country  income
# 0                   8   United-States   <=50K
# 1                  15   United-States   <=50K
# 2                  17   United-States   <=50K
# 3                  15   United-States   <=50K
# 4                  10   United-States   <=50K
# 5                  30   United-States   <=50K
# 6                  15   United-States   <=50K
# 7                  12   United-States   <=50K
# 8                  20   United-States   <=50K
# 9                   8   United-States   <=50K
# 10                 20   United-States   <=50K
# 11                 30   United-States   <=50K
# 12                 20   United-States   <=50K
# 13                 24   United-States   <=50K
# 14                 17   United-States   <=50K
# 15                 40   United-States   <=50K
# 16                 20   United-States   <=50K
# 17                  6   United-States   <=50K
# 18                 18   United-States   <=50K
# 19                  7   United-States   <=50K
# 20                 30   United-States   <=50K
# 21                 16   United-States   <=50K
# 22                 10   United-States   <=50K
# 23                 20   United-States   <=50K
# 24                 10   United-States   <=50K
# 25                 12   United-States   <=50K
# 26                 10          Canada   <=50K
# 27                  7   United-States   <=50K
# 28                 20   United-States   <=50K
# 29                 15   United-States   <=50K
# ...               ...             ...     ...
# 32531              10   United-States   <=50K
# 32532              50         Ecuador    >50K
# 32533              40   United-States   <=50K
# 32534              40   United-States   <=50K
# 32535              40   United-States   <=50K
# 32536              99   United-States   <=50K
# 32537              40   United-States   <=50K
# 32538              35   United-States   <=50K
# 32539              20               ?   <=50K
# 32540              40   United-States    >50K
# 32541              40   United-States   <=50K
# 32542              20     Philippines   <=50K
# 32543              72   United-States    >50K
# 32544              40   United-States   <=50K
# 32545              40   United-States   <=50K
# 32546              40   United-States    >50K
# 32547              15   United-States   <=50K
# 32548              10   United-States   <=50K
# 32549              24   United-States   <=50K
# 32550              37   United-States   <=50K
# 32551              15   United-States    >50K
# 32552               4   United-States   <=50K
# 32553              30   United-States   <=50K
# 32554              55   United-States   <=50K
# 32555              40         England    >50K
# 32556              12   United-States   <=50K
# 32557              25   United-States   <=50K
# 32558              35   United-States   <=50K
# 32559              40   United-States   <=50K
# 32560              40   United-States   <=50K
#
# [32561 rows x 15 columns]

# %%
print(df[df.age<25].groupby('marital-status').mean()['age'])
# replace column values based on conditions on other columns
df.loc[df['age']<25, 'marital-status'] = 'single'
print(df[df.age<25].groupby('marital-status').mean()['age'])
# Out:
# marital-status
#  Divorced                 22.505495
#  Married-AF-spouse        21.000000
#  Married-civ-spouse       22.515924
#  Married-spouse-absent    21.685714
#  Never-married            20.701676
#  Separated                22.277778
#  Widowed                  20.666667
# Name: age, dtype: float64
# marital-status
# single    20.911311
# Name: age, dtype: float64

# %%
# merge two dataframes
pd.merge(df, df, left_index=True, right_index=True)
# Out:
#        age_x        workclass_x  fnlwgt_x  education_x  education-num_x  \
# 0         39          State-gov     77516    Bachelors               13
# 1         50   Self-emp-not-inc     83311    Bachelors               13
# 2         38            Private    215646      HS-grad                9
# 3         53            Private    234721         11th                7
# 4         28            Private    338409    Bachelors               13
# ...      ...                ...       ...          ...              ...
# 32556     27            Private    257302   Assoc-acdm               12
# 32557     40            Private    154374      HS-grad                9
# 32558     58            Private    151910      HS-grad                9
# 32559     22            Private    201490      HS-grad                9
# 32560     52       Self-emp-inc    287927      HS-grad                9
#
#           marital-status_x        occupation_x  relationship_x  race_x  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559               single        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#          sex_x  ...     marital-status_y        occupation_y  relationship_y  \
# 0         Male  ...        Never-married        Adm-clerical   Not-in-family
# 1         Male  ...   Married-civ-spouse     Exec-managerial         Husband
# 2         Male  ...             Divorced   Handlers-cleaners   Not-in-family
# 3         Male  ...   Married-civ-spouse   Handlers-cleaners         Husband
# 4       Female  ...   Married-civ-spouse      Prof-specialty            Wife
# ...        ...  ...                  ...                 ...             ...
# 32556   Female  ...   Married-civ-spouse        Tech-support            Wife
# 32557     Male  ...   Married-civ-spouse   Machine-op-inspct         Husband
# 32558   Female  ...              Widowed        Adm-clerical       Unmarried
# 32559     Male  ...               single        Adm-clerical       Own-child
# 32560   Female  ...   Married-civ-spouse     Exec-managerial            Wife
#
#        race_y    sex_y  capital-gain_y capital-loss_y  hours-per-week_y  \
# 0       White     Male            2174              0                40
# 1       White     Male               0              0                13
# 2       White     Male               0              0                40
# 3       Black     Male               0              0                40
# 4       Black   Female               0              0                40
# ...       ...      ...             ...            ...               ...
# 32556   White   Female               0              0                38
# 32557   White     Male               0              0                40
# 32558   White   Female               0              0                40
# 32559   White     Male               0              0                20
# 32560   White   Female           15024              0                40
#
#       native-country_y  income_y
# 0        United-States     <=50K
# 1        United-States     <=50K
# 2        United-States     <=50K
# 3        United-States     <=50K
# 4                 Cuba     <=50K
# ...                ...       ...
# 32556    United-States     <=50K
# 32557    United-States      >50K
# 32558    United-States     <=50K
# 32559    United-States     <=50K
# 32560    United-States      >50K
#
# [32537 rows x 30 columns]

# %% [markdown]
# ___
# ## groupby

# %%
# group by method
df.groupby('sex')['hours-per-week'].mean()
# Out:
# sex
#  Female    36.410361
#  Male      42.428086
# Name: hours-per-week, dtype: float64

# %%
# group by method with multiple stat values
df.groupby('sex')['hours-per-week'].agg(['mean', 'max', 'min', 'std', 'sum'])
# Out:
#               mean  max  min        std     sum
# sex
#  Female  36.410361   99    1  11.811300  392176
#  Male    42.428086   99    1  12.119755  924508

# %%
# get distribution of column
df.groupby('sex')[['age', 'hours-per-week']].describe()
# Out:
#              age                                                      \
#            count       mean        std   min   25%   50%   75%   max
# sex
#  Female  10771.0  36.858230  14.013697  17.0  25.0  35.0  46.0  90.0
#  Male    21790.0  39.433547  13.370630  17.0  29.0  38.0  48.0  90.0
#
#         hours-per-week
#                  count       mean        std  min   25%   50%   75%   max
# sex
#  Female        10771.0  36.410361  11.811300  1.0  30.0  40.0  40.0  99.0
#  Male          21790.0  42.428086  12.119755  1.0  40.0  40.0  49.0  99.0

# %%
# to get distribution across values in multiple columns
df.groupby(['education', 'sex']).size().reset_index()
# Out:
#         education      sex     0
# 0            10th   Female   295
# 1            10th     Male   638
# 2            11th   Female   432
# 3            11th     Male   743
# 4            12th   Female   144
# 5            12th     Male   289
# 6         1st-4th   Female    46
# 7         1st-4th     Male   122
# 8         5th-6th   Female    84
# 9         5th-6th     Male   249
# 10        7th-8th   Female   160
# 11        7th-8th     Male   486
# 12            9th   Female   144
# 13            9th     Male   370
# 14     Assoc-acdm   Female   421
# 15     Assoc-acdm     Male   646
# 16      Assoc-voc   Female   500
# 17      Assoc-voc     Male   882
# 18      Bachelors   Female  1619
# 19      Bachelors     Male  3736
# 20      Doctorate   Female    86
# 21      Doctorate     Male   327
# 22        HS-grad   Female  3390
# 23        HS-grad     Male  7111
# 24        Masters   Female   536
# 25        Masters     Male  1187
# 26      Preschool   Female    16
# 27      Preschool     Male    35
# 28    Prof-school   Female    92
# 29    Prof-school     Male   484
# 30   Some-college   Female  2806
# 31   Some-college     Male  4485

# %%
df.groupby('education')['age'].describe().transpose()
# Out:
# education        10th         11th        12th     1st-4th     5th-6th  \
# count      933.000000  1175.000000  433.000000  168.000000  333.000000
# mean        37.429796    32.355745   32.000000   46.142857   42.885886
# std         16.720713    15.545485   14.334625   15.615625   15.557285
# min         17.000000    17.000000   17.000000   19.000000   17.000000
# 25%         22.000000    18.000000   19.000000   33.000000   29.000000
# 50%         34.000000    28.000000   28.000000   46.000000   42.000000
# 75%         52.000000    43.000000   41.000000   57.000000   54.000000
# max         90.000000    90.000000   79.000000   90.000000   84.000000
#
# education    7th-8th         9th   Assoc-acdm    Assoc-voc    Bachelors  \
# count      646.00000  514.000000  1067.000000  1382.000000  5355.000000
# mean        48.44582   41.060311    37.381443    38.553546    38.904949
# std         16.09235   15.946862    11.095177    11.631300    11.912210
# min         17.00000   17.000000    19.000000    19.000000    19.000000
# 25%         34.25000   28.000000    29.000000    30.000000    29.000000
# 50%         50.00000   39.000000    36.000000    37.000000    37.000000
# 75%         61.00000   54.000000    44.000000    46.000000    46.000000
# max         90.00000   90.000000    90.000000    84.000000    90.000000
#
# education   Doctorate       HS-grad      Masters   Preschool   Prof-school  \
# count      413.000000  10501.000000  1723.000000   51.000000    576.000000
# mean        47.702179     38.974479    44.049913   42.764706     44.746528
# std         11.784716     13.541524    11.068935   15.126914     11.962477
# min         24.000000     17.000000    18.000000   19.000000     25.000000
# 25%         39.000000     28.000000    36.000000   31.000000     36.000000
# 50%         47.000000     37.000000    43.000000   41.000000     43.000000
# 75%         55.000000     48.000000    51.000000   53.500000     51.000000
# max         80.000000     90.000000    90.000000   75.000000     90.000000
#
# education   Some-college
# count        7291.000000
# mean           35.756275
# std            13.474051
# min            17.000000
# 25%            24.000000
# 50%            34.000000
# 75%            45.000000
# max            90.000000

# %%
# applying groupby while keeping all the other columns intact
def is_senior_citizen(data):
    # takes dataframe grouped by a particular age and returns the new dataframe with additional column
    data['senior_citizen'] = data['age']>60
    return data
df = df.groupby('age').apply(is_senior_citizen)
df[df['age'].isin([58, 70, 62])]
# Out:
#        age      workclass  fnlwgt      education  education-num  \
# 144     70        Private  105376   Some-college             10
# 189     58      State-gov  109567      Doctorate             16
# 208     58   Self-emp-inc  210563        HS-grad              9
# 246     58        Private  236596        HS-grad              9
# 254     58        Private  259014   Some-college             10
# ...    ...            ...     ...            ...            ...
# 32460   62        Private  128092        HS-grad              9
# 32463   58      Local-gov  223214        HS-grad              9
# 32469   58   Self-emp-inc  181974      Doctorate             16
# 32522   58        Private  147707           11th              7
# 32558   58        Private  151910        HS-grad              9
#
#             marital-status         occupation     relationship    race  \
# 144          Never-married       Tech-support   Other-relative   White
# 189     Married-civ-spouse     Prof-specialty          Husband   White
# 208     Married-civ-spouse              Sales             Wife   White
# 246     Married-civ-spouse       Adm-clerical          Husband   White
# 254          Never-married   Transport-moving    Not-in-family   White
# ...                    ...                ...              ...     ...
# 32460              Widowed       Adm-clerical    Not-in-family   White
# 32463   Married-civ-spouse      Other-service          Husband   White
# 32469        Never-married     Prof-specialty    Not-in-family   White
# 32522   Married-civ-spouse              Sales          Husband   White
# 32558              Widowed       Adm-clerical        Unmarried   White
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 144       Male             0             0              40   United-States
# 189       Male             0             0               1   United-States
# 208     Female         15024             0              35   United-States
# 246       Male             0             0              45   United-States
# 254       Male             0             0              20   United-States
# ...        ...           ...           ...             ...             ...
# 32460   Female             0             0              32   United-States
# 32463     Male             0             0              40   United-States
# 32469   Female             0             0              99               ?
# 32522     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
#
#        income  senior_citizen
# 144     <=50K            True
# 189      >50K           False
# 208      >50K           False
# 246      >50K           False
# 254     <=50K           False
# ...       ...             ...
# 32460   <=50K            True
# 32463   <=50K           False
# 32469   <=50K           False
# 32522   <=50K           False
# 32558   <=50K           False
#
# [713 rows x 16 columns]

# %%
# get average hours per week based on occupation
df['average_hours'] = round(df.groupby('occupation').transform(mean)['hours-per-week'])
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income  \
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K
#
#    average_hours
# 0           38.0
# 1           45.0
# 2           38.0
# 3           38.0
# 4           42.0

# %% [markdown]
# ___
# ## pivot function of pandas
# Helpful when you have to assign a column as index or set columns values as header or some other interchange

# %%
df = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two',
                           'two'],
                   'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'baz': [1, 2, 3, 4, 5, 6],
                   'zoo': ['x', 'y', 'z', 'q', 'w', 't']})
df
# Out:
#    foo bar  baz zoo
# 0  one   A    1   x
# 1  one   B    2   y
# 2  one   C    3   z
# 3  two   A    4   q
# 4  two   B    5   w
# 5  two   C    6   t

# %%
df.pivot(index='foo', columns='bar', values='zoo')
# Out:
# bar  A  B  C
# foo
# one  x  y  z
# two  q  w  t

# %%
df.pivot(index='foo', columns='bar', values=['zoo', 'baz'])
# Out:
#     zoo       baz
# bar   A  B  C   A  B  C
# foo
# one   x  y  z   1  2  3
# two   q  w  t   4  5  6

# %% [markdown]
# ___
# ## melt function
# used to melt multiple columns into single column<br>
# Pandas.melt() unpivots a DataFrame from wide format to long format.
# melt() function is useful to massage a DataFrame into a format where one or more columns are identifier variables, while all other columns, considered measured variables, are unpivoted to the row axis, leaving just two non-identifier columns, variable and value.

# %%
df = pd.DataFrame({'City':['Jaipur', 'Bangalore', 'Chennai'], 'State':['Rajasthan', 'Karnataka', 'Tamilnadu'], 
                   'Mango':[14, 32, 65], 'Orange':[93, 34, 21], 'Pineapple':[87, 84, 37]})
df
# Out:
#         City      State  Mango  Orange  Pineapple
# 0     Jaipur  Rajasthan     14      93         87
# 1  Bangalore  Karnataka     32      34         84
# 2    Chennai  Tamilnadu     65      21         37

# %%
df.melt(id_vars=['City', 'State'], value_vars=['Mango', 'Orange', 'Pineapple'], var_name='Fruit', value_name='Pounds')
# Out:
#         City      State      Fruit  Pounds
# 0     Jaipur  Rajasthan      Mango      14
# 1  Bangalore  Karnataka      Mango      32
# 2    Chennai  Tamilnadu      Mango      65
# 3     Jaipur  Rajasthan     Orange      93
# 4  Bangalore  Karnataka     Orange      34
# 5    Chennai  Tamilnadu     Orange      21
# 6     Jaipur  Rajasthan  Pineapple      87
# 7  Bangalore  Karnataka  Pineapple      84
# 8    Chennai  Tamilnadu  Pineapple      37
